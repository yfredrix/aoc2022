# %%
blueprintdata = """Blueprint 1: Each ore robot costs 4 ore. Each clay robot costs 2 ore. Each obsidian robot costs 3 ore and 14 clay. Each geode robot costs 2 ore and 7 obsidian.
Blueprint 2: Each ore robot costs 2 ore. Each clay robot costs 3 ore. Each obsidian robot costs 3 ore and 8 clay. Each geode robot costs 3 ore and 12 obsidian.""".split("\n")

# %%
with open("input.txt") as file:
    blueprintdata = file.read().split("\n")

# %%
from typing import Dict, List, Tuple
from parse import parse
from nested_lookup import nested_lookup

# %%
def update_storage(robots: Dict[str, int], storage: Dict[str, int]) -> Dict[str, int]:
    for robot in robots:
        storage[robot.split("_")[0]] += robots[robot]
    return storage

# %%
def buildable_robots(
    robots: Dict[str, int],
    storage: Dict[str, int],
    blueprint: Dict[str, Dict[str, int]],
) -> List[str]:
    buildable_bots = []
    for robot in robots:
        robot_resources = nested_lookup(robot.split("_")[0], blueprint)
        if robot_resources:
            if all(
                [
                    storage[requirement] >= blueprint[robot][requirement]
                    for requirement in blueprint[robot]
                ]
            ) and robots[robot] < max(robot_resources):
                buildable_bots.append(robot)
        else:
            if all(
                [
                    storage[requirement] >= blueprint[robot][requirement]
                    for requirement in blueprint[robot]
                ]
            ):
                buildable_bots.append(robot)
    return buildable_bots

# %%
def build_robot(robot_to_be_build: str, robots: Dict[str, int], storage: Dict[str, int], blueprint:Dict[str, Dict[str, int]]) -> Tuple[Dict[str, int],Dict[str, int]]:
    robots[robot_to_be_build] += 1
    costs = blueprint[robot_to_be_build]
    for item in costs:
        storage[item] -= costs[item]
    return robots, storage

# %%
def search_best(time_left:int, storage: Dict[str, int], robots: Dict[str, int], blueprint: Dict[str, Dict[str, int]], lowest):
    if time_left == 0:
        return storage["geode"]
    
    if storage["geode"] + time_left * robots["geode_robot"] + time_left * (time_left -1) /2 <= lowest:
        return 0
    
    possible_builds = buildable_robots(robots=robots, storage=storage, blueprint=blueprint)
    
    time_left -= 1
    storage = update_storage(storage=storage, robots=robots)
    
    best = lowest
    
    if "geode_robot" in possible_builds:
        gd_robots, gd_storage = build_robot("geode_robot", robots.copy(), storage.copy(), blueprint)
        best = max(best, search_best(time_left, gd_storage, gd_robots, blueprint, best))
    
    if "obsidian_robot" in possible_builds:
        ob_robots, ob_storage = build_robot("obsidian_robot", robots.copy(), storage.copy(), blueprint)
        best = max(best, search_best(time_left, ob_storage, ob_robots, blueprint, best))
    
    if "clay_robot" in possible_builds:
        cl_robots, cl_storage = build_robot("clay_robot", robots.copy(), storage.copy(), blueprint)
        best = max(best, search_best(time_left, cl_storage, cl_robots, blueprint, best))
    
    if "ore_robot" in possible_builds:
        or_robots, or_storage = build_robot("ore_robot", robots.copy(), storage.copy(), blueprint)
        best = max(best, search_best(time_left, or_storage, or_robots, blueprint, best))
    
    best = max(best, search_best(time_left, storage, robots, blueprint, best))
    return best

# %%
blueprints = {}
for blueprint in blueprintdata:
    matches = parse(
        "Blueprint {}: Each ore robot costs {} ore. Each clay robot costs {} ore. Each obsidian robot costs {} ore and {} clay. Each geode robot costs {} ore and {} obsidian.",
        blueprint,
    )
    blueprints[matches[0]] = {
        "ore_robot": {"ore": int(matches[1])},
        "clay_robot": {"ore": int(matches[2])},
        "obsidian_robot": {
            "ore": int(matches[3]),
            "clay": int(matches[4]),
        },
        "geode_robot": {"ore": int(matches[5]), "obsidian": int(matches[6])},
    }

# %%
## Way to opportunistic building method
end_result = {}
for blueprint in blueprints:
    robots_to_be_build = []
    storage = {"ore":0, "clay": 0, "obsidian": 0, "geode":0}
    robots = {"ore_robot":1, "clay_robot": 0, "obsidian_robot": 0, "geode_robot":0}
    for time in range(1,25):
        storage = update_storage(robots=robots, storage=storage)
        if robots_to_be_build:
            robots, storage = build_robot(robots_to_be_build[0], robots, storage, blueprints[blueprint])
        print(f"At time {time} there are {robots}, which gives {storage}")
        robots_to_be_build = buildable_robots(robots=robots, storage=storage, blueprint=blueprints[blueprint])
    end_result[blueprint] = {"storage": storage.copy(),
                             "robots": robots.copy()}
# Out:
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 7, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 9, 'clay': 21, 'obsidian': 1, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 11, 'clay': 21, 'obsidian': 3, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 4, 'geode_robot': 0}, which gives {'ore': 13, 'clay': 21, 'obsidian': 6, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 5, 'geode_robot': 0}, which gives {'ore': 15, 'clay': 21, 'obsidian': 10, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 6, 'geode_robot': 0}, which gives {'ore': 17, 'clay': 21, 'obsidian': 15, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 7, 'geode_robot': 0}, which gives {'ore': 19, 'clay': 21, 'obsidian': 21, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 2, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 5, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 7, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 9, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 12, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 18, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 22, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 26, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 30, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 35, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 40, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 51, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 57, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 63, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 70, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 77, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 2, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 5, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 7, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 9, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 12, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 18, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 22, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 26, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 30, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 35, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 40, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 51, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 57, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 63, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 70, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 77, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 15, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 105, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 15, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 105, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 15, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 8, 'clay': 105, 'obsidian': 1, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 15, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 10, 'clay': 105, 'obsidian': 3, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 3, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 3, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 3, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 3, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 3, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 3, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 3, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 3, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 3, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 3, 'clay_robot': 13, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 78, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 3, 'clay_robot': 14, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 91, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 3, 'clay_robot': 15, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 105, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 3, 'clay_robot': 16, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 120, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 3, 'clay_robot': 17, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 136, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 3, 'clay_robot': 17, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 136, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 3, 'clay_robot': 17, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 136, 'obsidian': 1, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 7, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 9, 'clay': 28, 'obsidian': 1, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 11, 'clay': 28, 'obsidian': 3, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 4, 'geode_robot': 0}, which gives {'ore': 13, 'clay': 28, 'obsidian': 6, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 5, 'geode_robot': 0}, which gives {'ore': 15, 'clay': 28, 'obsidian': 10, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 6, 'geode_robot': 0}, which gives {'ore': 17, 'clay': 28, 'obsidian': 15, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 2, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 5, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 7, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 9, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 12, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 18, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 22, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 26, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 30, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 35, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 40, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 51, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 57, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 63, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 70, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 1, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 77, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 12, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 1, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 2, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 5, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 7, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 9, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 12, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 18, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 22, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 26, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 30, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 35, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 40, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 45, 'obsidian': 0, 'geode': 0}
# ...
# At time 19 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 24, 'obsidian': 4, 'geode': 0}
# At time 20 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 10, 'obsidian': 5, 'geode': 0}
# At time 21 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 15, 'obsidian': 7, 'geode': 0}
# At time 22 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 20, 'obsidian': 9, 'geode': 0}
# At time 23 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 25, 'obsidian': 11, 'geode': 0}
# At time 24 there are {'ore_robot': 1, 'clay_robot': 6, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 31, 'obsidian': 13, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 3, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 3, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 3, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 3, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 3, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 3, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 3, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 3, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 3, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 66, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 7, 'clay': 66, 'obsidian': 1, 'geode': 0}
# At time 22 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 8, 'clay': 66, 'obsidian': 3, 'geode': 0}
# At time 23 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 4, 'geode_robot': 0}, which gives {'ore': 9, 'clay': 66, 'obsidian': 6, 'geode': 0}
# At time 24 there are {'ore_robot': 3, 'clay_robot': 12, 'obsidian_robot': 5, 'geode_robot': 0}, which gives {'ore': 10, 'clay': 66, 'obsidian': 10, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 1, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 2, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 5, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 1, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 7, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 9, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 12, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 1, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 18, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 22, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 1, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 26, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 30, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 35, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 40, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 1, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 2, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 50, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 2, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 2, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 60, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 3, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 65, 'obsidian': 0, 'geode': 0}
# At time 24 there are {'ore_robot': 3, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 70, 'obsidian': 0, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 9, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 36, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 10, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 45, 'obsidian': 0, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 7, 'clay': 55, 'obsidian': 0, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 9, 'clay': 55, 'obsidian': 1, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 11, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 11, 'clay': 55, 'obsidian': 3, 'geode': 0}
# At time 1 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 2 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 2, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 3 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 4 there are {'ore_robot': 1, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 4, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 5 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 1, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 6 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 7 there are {'ore_robot': 2, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 8 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 3, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 9 there are {'ore_robot': 3, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 6, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 10 there are {'ore_robot': 4, 'clay_robot': 0, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 11 there are {'ore_robot': 4, 'clay_robot': 1, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 0, 'obsidian': 0, 'geode': 0}
# At time 12 there are {'ore_robot': 4, 'clay_robot': 2, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 1, 'obsidian': 0, 'geode': 0}
# At time 13 there are {'ore_robot': 4, 'clay_robot': 3, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 3, 'obsidian': 0, 'geode': 0}
# At time 14 there are {'ore_robot': 4, 'clay_robot': 4, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 6, 'obsidian': 0, 'geode': 0}
# At time 15 there are {'ore_robot': 4, 'clay_robot': 5, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 10, 'obsidian': 0, 'geode': 0}
# At time 16 there are {'ore_robot': 4, 'clay_robot': 6, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 15, 'obsidian': 0, 'geode': 0}
# At time 17 there are {'ore_robot': 4, 'clay_robot': 7, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 21, 'obsidian': 0, 'geode': 0}
# At time 18 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 0, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 19 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 1, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 0, 'geode': 0}
# At time 20 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 2, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 1, 'geode': 0}
# At time 21 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 3, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 3, 'geode': 0}
# At time 22 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 4, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 6, 'geode': 0}
# At time 23 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 5, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 10, 'geode': 0}
# At time 24 there are {'ore_robot': 4, 'clay_robot': 8, 'obsidian_robot': 6, 'geode_robot': 0}, which gives {'ore': 5, 'clay': 28, 'obsidian': 15, 'geode': 0}

# %%
quality = 0
for i in end_result:
    quality += int(i) * end_result[i]["storage"]["geode"]
quality # Needs to be larger than 1295
# Out:
# 0

# %%
# Progress bar on a single-machine scheduler
import dask

# %%
from tqdm import tqdm
from dask.distributed import Client, progress
client = Client(threads_per_worker=4, n_workers=3)
client
# Out:
# <Client: 'tcp://127.0.0.1:62136' processes=3 threads=12, memory=63.93 GiB>

# %%
def run_blueprint(blueprint, max_time=24):
    end_result = {}
    storage = {"ore":0, "clay": 0, "obsidian": 0, "geode":0}
    robots = {"ore_robot":1, "clay_robot": 0, "obsidian_robot": 0, "geode_robot":0}
    end_result[blueprint] = search_best(max_time, storage, robots, blueprints[blueprint], 0)
    return end_result

# %%
end_result = {}
lazy_results = []
for blueprint in blueprints:
    lazy_result = dask.delayed(run_blueprint)(blueprint)
    lazy_results.append(lazy_result)

# %%
all_results = dask.compute(*lazy_results)

# %%
all_results
# Out:
# ({'1': 3},
#  {'2': 1},
#  {'3': 0},
#  {'4': 0},
#  {'5': 9},
#  {'6': 0},
#  {'7': 6},
#  {'8': 2},
#  {'9': 6},
#  {'10': 4},
#  {'11': 2},
#  {'12': 0},
#  {'13': 0},
#  {'14': 1},
#  {'15': 0},
#  {'16': 3},
#  {'17': 0},
#  {'18': 3},
#  {'19': 0},
#  {'20': 2},
#  {'21': 3},
#  {'22': 3},
#  {'23': 8},
#  {'24': 1},
#  {'25': 16},
#  {'26': 0},
#  {'27': 5},
#  {'28': 7},
#  {'29': 3},
#  {'30': 1})

# %%
for result in all_results:
    end_result |= result
quality = 0
for i in end_result:
    quality += int(i) * end_result[i]
quality
# Out:
# 1565

# %%
end_result
# Out:
# {}

# %%
import math
end_result = {}
lazy_results = []
for blueprint in ["1","2","3"]:
    lazy_result = dask.delayed(run_blueprint)(blueprint, 32)
    lazy_results.append(lazy_result)
    
all_results = dask.compute(*lazy_results)

elephant_result = {}
for result in all_results:
    elephant_result |= result

math.prod(elephant_result.values())
# Out:
# 10672

# %%
elephant_result
# Out:
# {'1': 29, '2': 23, '3': 16}
